# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto=pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\jasobanta  das\Python Libraries\New data\auto+mpg\auto-mpg.data",header=None,delim_whitespace=True)
auto
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# renaming the columns name
auto.columns=["mpg","cylinder","diaplacement","horsepower","weight","acceleration","multi-valued","origin","car name"]
auto.head()
# Out:
#     mpg  cylinder  diaplacement horsepower  weight  acceleration  \
# 0  18.0         8         307.0      130.0  3504.0          12.0
# 1  15.0         8         350.0      165.0  3693.0          11.5
# 2  18.0         8         318.0      150.0  3436.0          11.0
# 3  16.0         8         304.0      150.0  3433.0          12.0
# 4  17.0         8         302.0      140.0  3449.0          10.5
#
#    multi-valued  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinder          int64
# diaplacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# multi-valued      int64
# origin            int64
# car name         object
# dtype: object

# %%
# check unique values
for i in auto.columns:
    print(i,":",auto[i].unique(),"\n")
# Out:
# mpg : [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# cylinder : [8 4 6 3 5]
#
# diaplacement : [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
for i in auto.columns:
    print(i,":",sum(auto[i]=='?'))
# Out:
# mpg : 0
# cylinder : 0
# diaplacement : 0
# horsepower : 6
# weight : 0
# acceleration : 0
# multi-valued : 0
# origin : 0
# car name : 0

# %%
# describe
d=auto.describe(include="all")
d
# Out:
#                mpg    cylinder  diaplacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  multi-valued      origin    car name
# count     398.000000    398.000000  398.000000         398
# ...

# %%
auto.horsepower.replace("?",d["horsepower"][2],inplace=True)

# %%
for i in auto.columns:
    print(i,":",sum(auto[i]=='?'))
# Out:
# mpg : 0
# cylinder : 0
# diaplacement : 0
# horsepower : 0
# weight : 0
# acceleration : 0
# multi-valued : 0
# origin : 0
# car name : 0

# %%
auto["horsepower"]=auto["horsepower"].astype("float64")

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinder          int64
# diaplacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# multi-valued      int64
# origin            int64
# car name         object
# dtype: object

# %%
plt.hist(auto["mpg"])
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(auto["weight"], auto["mpg"])
plt.title("Scatter plot")
plt.xlabel("weight")
plt.ylabel("mpg")
plt.show()

# %%
plt.scatter(auto["cylinder"], auto["mpg"])
plt.title("Scatter plot")
plt.xlabel("cylinder")
plt.ylabel("mpg")
plt.show()

# %%
plt.scatter(auto["horsepower"], auto["mpg"])
plt.title("Scatter plot")
plt.xlabel("horsepower")
plt.ylabel("mpg")
plt.show()

# %%
plt.scatter(auto["acceleration"], auto["mpg"])
plt.title("Scatter plot")
plt.xlabel("acceleration")
plt.ylabel("mpg")
plt.show()

# %%
plt.scatter(auto["diaplacement"], auto["mpg"])
plt.title("Scatter plot")
plt.xlabel("displacement")
plt.ylabel("mpg")
plt.show()

# %%
a=sns.pairplot(auto[["mpg","cylinder","diaplacement",
                 "horsepower","weight",
                 "acceleration"]])
a

# %%
ip=auto.drop(["mpg","car name"],axis=1)
ip
# Out:
#      cylinder  diaplacement  horsepower  weight  acceleration  multi-valued  \
# 0           8         307.0       130.0  3504.0          12.0            70
# 1           8         350.0       165.0  3693.0          11.5            70
# 2           8         318.0       150.0  3436.0          11.0            70
# 3           8         304.0       150.0  3433.0          12.0            70
# 4           8         302.0       140.0  3449.0          10.5            70
# ..        ...           ...         ...     ...           ...           ...
# 393         4         140.0        86.0  2790.0          15.6            82
# 394         4          97.0        52.0  2130.0          24.6            82
# 395         4         135.0        84.0  2295.0          11.6            82
# 396         4         120.0        79.0  2625.0          18.6            82
# 397         4         119.0        82.0  2720.0          19.4            82
#
#      origin
# 0         1
# 1         1
# 2         1
# ...

# %%
op=auto.mpg
op
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(ip,op,train_size=0.8)

# %%
xtrain
# Out:
#      cylinder  diaplacement  horsepower  weight  acceleration  multi-valued  \
# 16          6         199.0        97.0  2774.0          15.5            70
# 226         6         231.0       105.0  3425.0          16.9            77
# 54          4          72.0        69.0  1613.0          18.0            71
# 356         4         108.0        75.0  2350.0          16.8            81
# 159         8         351.0       148.0  4657.0          13.5            75
# ..        ...           ...         ...     ...           ...           ...
# 193         6         200.0        81.0  3012.0          17.6            76
# 387         6         262.0        85.0  3015.0          17.0            82
# 190         8         351.0       152.0  4215.0          12.8            76
# 127         6         232.0       100.0  2901.0          16.0            74
# 318         4         134.0        90.0  2711.0          15.5            80
#
#      origin
# 16        1
# 226       1
# 54        3
# ...

# %%
xtest
# Out:
#      cylinder  diaplacement  horsepower  weight  acceleration  multi-valued  \
# 378         4         105.0        63.0  2125.0          14.7            82
# 291         8         267.0       125.0  3605.0          15.0            79
# 373         4         140.0        92.0  2865.0          16.4            82
# 254         6         200.0        85.0  2965.0          15.8            78
# 45          6         258.0       110.0  2962.0          13.5            71
# ..        ...           ...         ...     ...           ...           ...
# 237         4          98.0        63.0  2051.0          17.0            77
# 307         6         173.0       115.0  2700.0          12.9            79
# 301         4         105.0        70.0  2200.0          13.2            79
# 116         8         400.0       230.0  4278.0           9.5            73
# 7           8         440.0       215.0  4312.0           8.5            70
#
#      origin
# 378       1
# 291       1
# 373       1
# ...

# %%
ytrain
# Out:
# 16     18.0
# 226    20.5
# 54     35.0
# 356    32.4
# 159    14.0
#        ...
# 193    24.0
# 387    38.0
# 190    14.5
# 127    19.0
# 318    29.8
# Name: mpg, Length: 318, dtype: float64

# %%
ytest
# Out:
# 378    38.0
# 291    19.2
# 373    24.0
# 254    20.2
# 45     18.0
#        ...
# 237    30.5
# 307    26.8
# 301    34.2
# 116    16.0
# 7      14.0
# Name: mpg, Length: 80, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)
xtrain
# Out:
# array([[ 0.30568466,  0.04810316, -0.21536828, ..., -0.01986382,
#         -1.6661779 , -0.71137182],
#        [ 0.30568466,  0.36118134,  0.00222382, ...,  0.50033463,
#          0.24464745, -0.71137182],
#        [-0.86549272, -1.19442588, -0.97694063, ...,  0.90906199,
#         -1.39320285,  1.77452091],
#        ...,
#        [ 1.47686204,  1.53522453,  1.28057741, ..., -1.0231037 ,
#         -0.0283276 , -0.71137182],
#        [ 0.30568466,  0.37096504, -0.13377124, ...,  0.16592134,
#         -0.5742777 , -0.71137182],
#        [-0.86549272, -0.5878369 , -0.40576137, ..., -0.01986382,
#          1.0635726 ,  1.77452091]])

# %%
xtest=sc.transform(xtest)
xtest
# Out:
# array([[-0.86549272, -0.87156401, -1.14013471, -1.02300189, -0.31712008,
#          1.6095227 , -0.71137182],
#        [ 1.47686204,  0.7133943 ,  0.54620407,  0.71990421, -0.20564898,
#          0.79059755, -0.71137182],
#        [-0.86549272, -0.52913474, -0.35136334, -0.15154884,  0.31454947,
#          1.6095227 , -0.71137182],
#        [ 0.30568466,  0.05788685, -0.54175643, -0.03378491,  0.09160727,
#          0.5176225 , -0.71137182],
#        [ 0.30568466,  0.62534106,  0.13821888, -0.03731783, -0.76300447,
#         -1.39320285, -0.71137182],
#        [-0.86549272, -1.00853571, -0.94974162, -1.22320056,  1.8379878 ,
#         -1.39320285, -0.71137182],
#        [ 0.30568466,  0.54707151, -0.13377124,  0.33952673, -0.20564898,
#         -1.39320285, -0.71137182],
#        [ 1.47686204,  2.55272863,  3.26610532,  0.10870943, -2.06350061,
#         -1.6661779 , -0.71137182],
#        [-0.86549272, -0.52913474, -0.8953436 , -0.50484062, -0.72584744,
# ...

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
pred=lr.predict(xtest)
pred
# Out:
# array([32.41129725, 21.10343607, 27.98507096, 24.47980737, 19.59521881,
#        25.43625372, 17.41778285, 20.14912498, 24.95873024, 34.90389345,
#        25.94068172, 18.1511432 , 20.71596389, 23.90629024, 20.93007029,
#        11.66168497, 27.4552548 , 31.93472332, 34.17837597, 16.94874882,
#        28.93056241, 20.14431668, 36.32222844, 33.92287165, 26.61211906,
#        23.76984517,  5.71263908, 20.35389308, 12.59462339, 25.8822555 ,
#        35.65505536, 31.02427344, 15.53426266, 25.68332344, 25.05493388,
#        10.9619459 , 28.29139989, 21.81463967, 32.06469774, 33.99869572,
#        20.69918166, 23.73039576, 20.61731265, 24.99626988, 12.18639836,
#        27.53157182, 28.76207106, 16.71387989, 31.75815211, 20.81549079,
#        17.3813181 , 24.74870301, 29.77948575, 27.48485038, 26.38721881,
#        15.32405216, 29.04758109, 26.31996641, 19.73061988, 25.76167803,
#        24.02103301, 34.57338401, 25.19691354, 20.84594352, 29.15616978,
# ...

# %%
ytest
# Out:
# 378    38.0
# 291    19.2
# 373    24.0
# 254    20.2
# 45     18.0
#        ...
# 237    30.5
# 307    26.8
# 301    34.2
# 116    16.0
# 7      14.0
# Name: mpg, Length: 80, dtype: float64

# %%
from sklearn.metrics import r2_score
r2=r2_score(ytest,pred)
r2
# Out:
# 0.7926594546135564

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_poly=poly.fit_transform(xtrain)
pol_reg=LinearRegression()

pol_reg.fit(x_poly,ytrain)
x1=poly.fit_transform(xtest)
yp2=pol_reg.predict(x1)

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,yp2)
r2=r2_score(ytest,yp2)
print(mse)
print(r2)
# Out:
# 92.54381725732763
# -0.5637963673072084

# %% [markdown]
# # lasso

# %%
from sklearn.linear_model import Lasso
L=Lasso(alpha=0.01)
L.fit(xtrain,ytrain)
yp3=L.predict(xtest)

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,yp3)
r2=r2_score(ytest,yp3)
print(mse)
print(r2)
# Out:
# 12.25445815964116
# 0.7929253652885422

# %% [markdown]
# # ridge

# %%
from sklearn.linear_model import Ridge
r=Ridge(alpha=1)
r.fit(xtrain,ytrain)
yp4=r.predict(xtest)

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,yp4)
r2=r2_score(ytest,yp4)
print(mse)
print(r2)
# Out:
# 12.205700008451483
# 0.7937492757556782

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
svr = SVR()              
svr.fit(xtrain, ytrain)
# Out:
# SVR()

# %%
pred = svr.predict(xtest) 
pred
# Out:
# array([32.2177038 , 18.8456897 , 27.86165828, 23.05355694, 18.75999573,
#        23.64500871, 17.81276335, 17.94221185, 26.64599932, 33.81476502,
#        25.05059637, 16.61835725, 23.09699805, 22.94287263, 18.39390086,
#        12.88451684, 22.97513736, 32.04370688, 33.05113578, 15.33787886,
#        28.58990303, 21.50240549, 34.34551626, 34.50853977, 26.64719009,
#        24.49678292, 13.56070751, 19.11097115, 14.8421853 , 26.81508655,
#        33.6007051 , 32.71642149, 15.69358379, 26.57485997, 25.45251644,
#        15.88353881, 28.92191957, 20.40295768, 31.5866458 , 27.03412873,
#        18.39249942, 21.8525694 , 22.12868495, 25.87181525, 13.88311955,
#        27.23058048, 28.8384099 , 14.68088905, 28.7309016 , 20.35691985,
#        18.02802337, 23.44566621, 29.68427477, 24.57632428, 24.3003576 ,
#        16.22538452, 25.62618147, 24.76641247, 17.37634053, 25.56339197,
#        25.14108552, 33.72094874, 24.93119719, 17.74769527, 28.69807382,
# ...

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,pred)
r2=r2_score(ytest,pred)
print(mse)
print(r2)
# Out:
# 11.83131103882402
# 0.8000756639252451

# %% [markdown]
# # Decission Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dr=DecisionTreeRegressor()

# %%
dr.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
pred1=r.predict(xtest)
pred1
# Out:
# array([32.41963774, 21.13910129, 28.02685904, 24.50803826, 19.49612298,
#        25.36769868, 17.4341436 , 19.41246468, 25.05250874, 34.79806312,
#        25.94303831, 18.14829927, 20.838985  , 23.98081119, 20.75662039,
#        11.52734149, 27.3033344 , 31.90224804, 34.08035875, 16.94716035,
#        28.8967531 , 20.31743033, 36.20612901, 33.87178015, 26.59933127,
#        23.80535534,  5.86078807, 20.4245976 , 12.73133659, 25.98140926,
#        35.5322193 , 31.06495872, 15.28682131, 25.73826467, 25.0792407 ,
#        10.67104204, 28.28918762, 21.97535346, 31.96801384, 33.72387354,
#        20.69612619, 23.63244032, 20.75009527, 25.07281787, 12.15493149,
#        27.49316922, 28.70339528, 16.53328064, 31.70476717, 20.77539748,
#        17.41860926, 24.69920053, 29.74021329, 27.46811673, 26.38886454,
#        15.27144999, 28.98707923, 26.33830718, 19.69792867, 25.8545375 ,
#        24.09298469, 34.5061181 , 25.22829162, 20.79100628, 29.15864969,
# ...

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,pred1)
r2=r2_score(ytest,pred1)
print(mse)
print(r2)
# Out:
# 12.205700008451483
# 0.7937492757556782

# %% [markdown]
# # Random forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
Rf=RandomForestRegressor()

# %%
Rf.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
pred2=r.predict(xtest)
pred2
# Out:
# array([32.41963774, 21.13910129, 28.02685904, 24.50803826, 19.49612298,
#        25.36769868, 17.4341436 , 19.41246468, 25.05250874, 34.79806312,
#        25.94303831, 18.14829927, 20.838985  , 23.98081119, 20.75662039,
#        11.52734149, 27.3033344 , 31.90224804, 34.08035875, 16.94716035,
#        28.8967531 , 20.31743033, 36.20612901, 33.87178015, 26.59933127,
#        23.80535534,  5.86078807, 20.4245976 , 12.73133659, 25.98140926,
#        35.5322193 , 31.06495872, 15.28682131, 25.73826467, 25.0792407 ,
#        10.67104204, 28.28918762, 21.97535346, 31.96801384, 33.72387354,
#        20.69612619, 23.63244032, 20.75009527, 25.07281787, 12.15493149,
#        27.49316922, 28.70339528, 16.53328064, 31.70476717, 20.77539748,
#        17.41860926, 24.69920053, 29.74021329, 27.46811673, 26.38886454,
#        15.27144999, 28.98707923, 26.33830718, 19.69792867, 25.8545375 ,
#        24.09298469, 34.5061181 , 25.22829162, 20.79100628, 29.15864969,
# ...

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,pred2)
r2=r2_score(ytest,pred2)
print(mse)
print(r2)
# Out:
# 12.205700008451483
# 0.7937492757556782

# %% [markdown]
# # Adaboost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
Ad=AdaBoostRegressor(n_estimators=100,learning_rate=0.01)

# %%
Ad.fit(xtrain,ytrain)
# Out:
# AdaBoostRegressor(learning_rate=0.01, n_estimators=100)

# %%
pred3=Ad.predict(xtest)
pred3
# Out:
# array([36.35348837, 18.72631579, 29.18545455, 19.61538462, 19.37118644,
#        29.125     , 18.87121212, 15.95      , 24.06973684, 36.40263158,
#        28.95945946, 18.72631579, 23.7755102 , 23.03333333, 16.        ,
#        13.59166667, 29.05416667, 35.80483871, 35.88636364, 15.19318182,
#        29.14888889, 23.67045455, 36.38684211, 36.40263158, 27.94117647,
#        23.98      , 13.55555556, 19.18636364, 13.91304348, 23.95081967,
#        36.38684211, 35.9462963 , 15.325     , 24.14915254, 23.7755102 ,
#        13.55555556, 28.27631579, 19.78139535, 29.48387097, 35.88636364,
#        19.03061224, 23.76774194, 23.71714286, 28.66071429, 13.6372549 ,
#        23.88965517, 24.10958904, 14.94081633, 34.10188679, 19.45492958,
#        18.97241379, 23.86727273, 29.125     , 28.44285714, 23.375     ,
#        15.553125  , 29.06818182, 23.75555556, 18.87121212, 24.09333333,
#        24.91269841, 33.7173913 , 24.56031746, 17.39333333, 27.41428571,
# ...

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,pred3)
r2=r2_score(ytest,pred3)
print(mse)
print(r2)
# Out:
# 9.599795774858098
# 0.837783590470756

# %% [markdown]
# # GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
Gd=GradientBoostingRegressor(n_estimators=100,learning_rate=0.01)

# %%
Gd.fit(xtrain,ytrain)
# Out:
# GradientBoostingRegressor(learning_rate=0.01)

# %%
pred4=Gd.predict(xtest)
pred4
# Out:
# array([31.51798891, 20.83681208, 26.42979511, 21.46271371, 20.93997394,
#        26.80955081, 20.36181483, 19.5481836 , 24.3337647 , 31.55037343,
#        25.50944227, 20.11074529, 23.62750434, 24.32929376, 18.85653892,
#        17.04570405, 25.79967626, 31.04299163, 31.07537615, 18.25042307,
#        27.03966669, 22.89531238, 31.55037343, 31.55037343, 25.74505965,
#        24.3337647 , 17.01340767, 21.08241359, 17.40526826, 24.08167461,
#        31.55037343, 31.07537615, 18.92281875, 24.93439916, 23.62750434,
#        17.26251109, 26.6607265 , 21.25444994, 27.94492323, 30.64021462,
#        20.41974983, 23.62750434, 22.96101909, 26.75617676, 17.04570405,
#        23.62750434, 24.08167461, 18.83018615, 30.0461625 , 22.08511762,
#        20.36181483, 24.01622108, 26.80955081, 25.48715355, 24.14688331,
#        18.92281875, 26.80955081, 23.62750434, 20.36181483, 23.23262539,
#        25.49296957, 28.91813127, 25.0387993 , 19.77397125, 25.74505965,
# ...

# %%
# accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(ytest,pred4)
r2=r2_score(ytest,pred4)
print(mse)
print(r2)
# Out:
# 16.453128058412563
# 0.7219766522376878
