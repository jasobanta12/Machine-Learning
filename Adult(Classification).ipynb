# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
adult=pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\jasobanta  das\Python Libraries\New data\adult\adult.data",header=None)

# %%
adult.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
adult.columns=['age',"workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","income"]

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
for i in adult.columns:
    print(i,":",adult[i].unique(),"\n")
# Out:
# age : [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# workclass : [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# fnlwgt : [ 77516  83311 215646 ...  34066  84661 257302]
#
# education : [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# education-num : [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# marital-status : [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# occupation : [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
# ...

# %%
for i in adult.columns:
    print(i,":",sum(adult[i]==' ?'))
# Out:
# age : 0
# workclass : 1836
# fnlwgt : 0
# education : 0
# education-num : 0
# marital-status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital-gain : 0
# capital-loss : 0
# hours-per-week : 0
# native-country : 583
# income : 0

# %%
a=adult.describe(include="all")
a
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     30725  3.256100e+04     32561   32561.000000
# unique           NaN         8           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital-status       occupation relationship    race    sex  \
# ...

# %%
adult.workclass.replace(' ?',np.nan,inplace=True)
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
for i in adult.columns:
    print(i,":",sum(adult[i]==' ?'))
# Out:
# age : 0
# workclass : 0
# fnlwgt : 0
# education : 0
# education-num : 0
# marital-status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital-gain : 0
# capital-loss : 0
# hours-per-week : 0
# native-country : 583
# income : 0

# %%
list=["occupation","native-country"]
for i in list:
    adult[i]=adult[i].replace(' ?',np.nan)

# %%
for i in adult.columns:
    print(i,":",sum(adult[i]==' ?'))
# Out:
# age : 0
# workclass : 0
# fnlwgt : 0
# education : 0
# education-num : 0
# marital-status : 0
# occupation : 0
# relationship : 0
# race : 0
# sex : 0
# capital-gain : 0
# capital-loss : 0
# hours-per-week : 0
# native-country : 0
# income : 0

# %%
adult.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
adult["workclass"] = adult["workclass"].fillna(a["workclass"][2])

# %%
adult["occupation"] = adult["occupation"].fillna(a["occupation"][2])

# %%
adult["native-country"] = adult["native-country"].fillna(a["native-country"][2])

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
sns.countplot(x="workclass", hue="income", data=adult)
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(adult["age"], kde=True)
plt.show()

# %%
sns.boxplot(x="income", y="age", data=adult)
plt.show()

# %%
sns.heatmap(adult.corr(), annot=True, cmap="coolwarm")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19240\579096438.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(adult.corr(), annot=True, cmap="coolwarm")

# %%
sns.violinplot(x="income", y="hours-per-week", data=adult)
plt.show()

# %%
sns.distplot(adult["age"])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19240\2132078918.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adult["age"])

# %%
sns.countplot(x="income", hue="sex", data=adult)
plt.show()

# %%
sns.countplot(x="income", data=adult)
plt.show()

# %%
adult.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in ["workclass","education","marital-status","occupation","native-country","income","sex"]:
    adult[i]=le.fit_transform(adult[i])

# %%
for i in adult.columns:
    print(i,":",adult[i].unique(),"\n")
# Out:
# age : [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# workclass : [6 5 3 0 1 4 7 2]
#
# fnlwgt : [ 77516  83311 215646 ...  34066  84661 257302]
#
# education : [ 9 11  1 12  6 15  7  8  5 10 14  4  0  3 13  2]
#
# education-num : [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# marital-status : [4 2 0 3 5 1 6]
#
# occupation : [ 0  3  5  9  7 11  2 13  4  6 12 10  1  8]
#
# relationship : [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
#
# race : [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
#
# sex : [1 0]
#
# capital-gain : [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
# ...

# %%
ip=adult.drop(["relationship","race","income","fnlwgt"],axis=1)
ip.head()
# Out:
#    age  workclass  education  education-num  marital-status  occupation  sex  \
# 0   39          6          9             13               4           0    1
# 1   50          5          9             13               2           3    1
# 2   38          3         11              9               0           5    1
# 3   53          3          1              7               2           5    1
# 4   28          3          9             13               2           9    0
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0          2174             0              40              38
# 1             0             0              13              38
# 2             0             0              40              38
# 3             0             0              40              38
# 4             0             0              40               4

# %%
op=adult.income

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(ip,op,train_size=0.85)

# %%
xtrain
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 26023   46          3          8             11               2           9
# 27730   22          3          6              5               4           9
# 22284   54          4         10             16               2           9
# 14741   32          3         11              9               2           3
# 7610    35          3         11              9               2           4
# ...    ...        ...        ...            ...             ...         ...
# 6572    64          3         11              9               4           0
# 24718   53          3         11              9               0          11
# 12174   52          6         12             14               2           9
# 17535   64          3          0              6               2           0
# 24674   25          3         11              9               5           2
#
# ...

# %%
ytrain
# Out:
# 26023    1
# 27730    0
# 22284    1
# 14741    1
# 7610     0
#         ..
# 6572     0
# 24718    0
# 12174    1
# 17535    0
# 24674    0
# Name: income, Length: 27676, dtype: int32

# %%
xtest
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 26566   30          3         11              9               5           9
# 742     42          3         12             14               4           3
# 31608   50          3          9             13               2           3
# 2974    53          3          1              7               2           2
# 24342   49          5          9             13               2           4
# ...    ...        ...        ...            ...             ...         ...
# 16955   21          3         11              9               4           0
# 4923    42          3         15             10               2          11
# 24039   26          3          0              6               4           2
# 2781    61          3         15             10               2          11
# 13717   30          3         11              9               0          13
#
# ...

# %%
ytest
# Out:
# 26566    0
# 742      1
# 31608    1
# 2974     0
# 24342    0
#         ..
# 16955    0
# 4923     1
# 24039    0
# 2781     1
# 13717    0
# Name: income, Length: 4885, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)

# %%
xtrain
# Out:
# array([[-1.51094511, -0.08578711,  1.21314309, ..., -0.21818785,
#         -2.06366161,  0.26165642],
#        [-0.33899687, -0.08578711,  0.18223366, ..., -0.21818785,
#          0.36491048,  0.26165642],
#        [-0.4854904 , -2.78673315,  1.21314309, ..., -0.21818785,
#         -0.03985153,  0.26165642],
#        ...,
#        [ 0.02723695, -0.08578711,  1.21314309, ..., -0.21818785,
#          1.57919653,  0.26165642],
#        [ 0.68645784, -0.08578711,  1.21314309, ..., -0.21818785,
#         -0.03985153,  0.26165642],
#        [-0.7052307 , -0.08578711, -0.59094841, ..., -0.21818785,
#          0.20300568,  0.26165642]])

# %%
xtext=sc.transform(xtest)
xtest
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 14959   19          3         11              9               4          11
# 6428    19          3         11              9               4           7
# 11351   49          4         11              9               2           2
# 31865   27          3          3              2               4           2
# 16886   20          3         15             10               4           7
# ...    ...        ...        ...            ...             ...         ...
# 13235   39          3         15             10               0           7
# 25891   42          3          2              8               4           4
# 9122    34          3         11              9               4           7
# 7304    23          3          9             13               2           9
# 13072   18          3          2              8               4           7
#
# ...

# %% [markdown]
# # Clssification model(Logistic and KNN)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pred=lr.predict(xtext)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(ytest,pred)
cm
# Out:
# array([[4655,  270],
#        [ 900,  688]], dtype=int64)

# %%
cmd=ConfusionMatrixDisplay(cm)
cmd.plot()
plt.show()

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc=accuracy_score(ytest,pred)
rec=recall_score(ytest,pred)
pre=precision_score(ytest,pred)
f1=f1_score(ytest,pred)

# %%
print(f"Accuracy score:{acc}\nRecall Score:{rec}\nprecision score:{pre} \nf1_score:{f1}")
# Out:
# Accuracy score:0.8203592814371258
# Recall Score:0.4332493702770781
# precision score:0.7181628392484343
# f1_score:0.5404556166535742

# %%
# plotting S-shape curve for classification model
df=pd.DataFrame({"ytest":ytest,"prediction":pred})
df.head()
# Out:
#        ytest  prediction
# 14959      0           0
# 6428       0           0
# 11351      0           0
# 31865      0           0
# 16886      0           0

# %%
sns.lmplot(x="ytest",y="prediction",data=df,logistic=True,scatter_kws={"color": "blue"},line_kws={"color": "purple"} )
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=15)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
pred1=knn.predict(xtest)
pred1
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(ytest,pred1)
cm
# Out:
# array([[4725,  200],
#        [1230,  358]], dtype=int64)

# %%
cmd=ConfusionMatrixDisplay(cm)
cmd.plot(cmap='Blues')
plt.show()

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc=accuracy_score(ytest,pred1)
rec=recall_score(ytest,pred1)
pre=precision_score(ytest,pred1)
f1=f1_score(ytest,pred1)

# %%
print(f"Accuracy score:{acc}\nRecall Score:{rec}\nprecision score:{pre} \nf1_score:{f1}")
# Out:
# Accuracy score:0.780439121756487
# Recall Score:0.22544080604534006
# precision score:0.6415770609318996
# f1_score:0.33364398881640256
